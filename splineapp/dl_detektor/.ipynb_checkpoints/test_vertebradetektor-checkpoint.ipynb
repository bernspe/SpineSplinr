# %%
import sys
sys.path.append('/Volumes/1TB/Users/peterbernstein/Django/SpineSplinr')

# %%
from fastai.vision import *
#from nb_helpers import *
from nb_heatmap import *
import torchvision.transforms as T
import numpy as np
import pandas as pd
import random
import scipy.interpolate as ip
from scipy.signal import argrelextrema
from PIL import ImageFont,ImageDraw,ImageColor
from vertebra_detector import CobbAngleDetector


defaults.device = torch.device('cpu')

# %%
modelpath='/Volumes/1TB/Users/peterbernstein/eclipse-workspace/scoliosis_deep_production/vertebrae_detection_model_new.pkl'
net_folder = Path(modelpath)
learn_model = load_learner(net_folder.parent, net_folder.name)
cad=CobbAngleDetector(learn_model)

# %% [markdown]
# ### Random Xray

# %%
imgdir='/Volumes/1TB/Users/peterbernstein/eclipse-workspace/Test1/ordbilder/xray_resized'
fNames = list(filter(lambda x: x.lower().endswith(('.png', '.jpg', '.jpeg')), os.listdir(imgdir)))
n=1
rlist=random.sample(list(fNames), n)
path2img = imgdir+'/'+rlist[0]
img_pil = PIL.Image.open(path2img)

# %% [markdown]
# ### Negativ Control

# %%
ntc_img='/Volumes/1TB/Users/peterbernstein/Documents/Fotos/IMG_5530.JPG'
img_pil=PIL.Image.open(ntc_img)

# %%
cad.fit(img_pil)

# %%
cad.generateCOBB()

# %%
cad.errors
# Out:
# []

# %%
cad.generateAnnotatedImage()

# %%
cad.errors

# %%
cad.annotated_image

# %%
[type(c) for c in cad.cobbdata]
# Out:
# [str, str, str, str, str, str, str]

# %%
cad.cobbdata
# Out:
# {'UpperVertebra': 'T1',
#  'LowerVertebra': 'L5',
#  'EndVertebrae': [('T8', 'L1'), ('L1', 'L4')],
#  'EndVertebraeIndices': [(7, 12), (12, 15)],
#  'COBBAngles': [32, 27],
#  'VertebraeCentroids': array([[ 89,  21],
#         [ 90,  40],
#         [ 92,  58],
#         [ 94,  78],
#         [ 98,  99],
#         [102, 120],
#         [107, 142],
#         [111, 163],
#         [116, 184],
#         [119, 205],
#         [118, 234],
#         [110, 262],
#         [ 99, 290],
#         [ 89, 319],
#         [ 83, 353],
#         [ 84, 388],
#         [ 92, 426]]),
#  'Spline': [(89, 21),
#   (88, 22),
#   (88, 23),
#   (88, 24),
#   (88, 25),
#   (89, 26),
#   (89, 27),
#   (89, 28),
#   (89, 29),
#   (89, 30),
#   (89, 31),
#   (89, 32),
#   (89, 33),
#   (89, 34),
#   (89, 35),
#   (89, 36),
#   (89, 37),
#   (89, 38),
#   (89, 39),
#   (90, 40),
#   (90, 41),
#   (90, 42),
#   (90, 43),
#   (90, 44),
#   (90, 45),
#   (90, 46),
#   (90, 47),
#   (90, 48),
#   (91, 49),
#   (91, 50),
#   (91, 51),
#   (91, 52),
#   (91, 53),
#   (91, 54),
#   (91, 55),
#   (91, 56),
#   (91, 57),
#   (92, 58),
#   (92, 59),
#   (92, 60),
#   (92, 61),
#   (92, 62),
#   (92, 63),
#   (92, 64),
#   (92, 65),
#   (92, 66),
#   (92, 67),
#   (92, 68),
#   (92, 69),
#   (93, 70),
#   (93, 71),
#   (93, 72),
#   (93, 73),
#   (93, 74),
#   (93, 75),
#   (93, 76),
#   (93, 77),
#   (93, 78),
#   (94, 79),
#   (94, 80),
#   (94, 81),
#   (94, 82),
#   (94, 83),
#   (94, 84),
#   (95, 85),
#   (95, 86),
#   (95, 87),
#   (95, 88),
#   (95, 89),
#   (96, 90),
#   (96, 91),
#   (96, 92),
#   (96, 93),
#   (96, 94),
#   (97, 95),
#   (97, 96),
#   (97, 97),
#   (97, 98),
#   (98, 99),
#   (98, 100),
#   (98, 101),
#   (98, 102),
#   (98, 103),
#   (98, 104),
#   (99, 105),
#   (99, 106),
#   (99, 107),
#   (99, 108),
#   (99, 109),
#   (100, 110),
#   (100, 111),
#   (100, 112),
#   (100, 113),
#   (100, 114),
#   (100, 115),
#   (101, 116),
#   (101, 117),
#   (101, 118),
#   (101, 119),
#   (101, 120),
#   (102, 121),
#   (102, 122),
#   (102, 123),
#   (102, 124),
#   (103, 125),
#   (103, 126),
#   (103, 127),
#   (103, 128),
#   (104, 129),
#   (104, 130),
#   (104, 131),
#   (104, 132),
#   (104, 133),
#   (105, 134),
#   (105, 135),
#   (105, 136),
#   (105, 137),
#   (106, 138),
#   (106, 139),
#   (106, 140),
#   (106, 141),
#   (107, 142),
#   (107, 143),
#   (107, 144),
#   (107, 145),
#   (107, 146),
#   (107, 147),
#   (108, 148),
#   (108, 149),
#   (108, 150),
#   (108, 151),
#   (108, 152),
#   (109, 153),
#   (109, 154),
#   (109, 155),
#   (109, 156),
#   (109, 157),
#   (109, 158),
#   (110, 159),
#   (110, 160),
#   (110, 161),
#   (110, 162),
#   (111, 163),
#   (111, 164),
#   (111, 165),
#   (111, 166),
#   (111, 167),
#   (112, 168),
#   (112, 169),
#   (112, 170),
#   (112, 171),
#   (113, 172),
#   (113, 173),
#   (113, 174),
#   (113, 175),
#   (114, 176),
#   (114, 177),
#   (114, 178),
#   (114, 179),
#   (115, 180),
#   (115, 181),
#   (115, 182),
#   (115, 183),
#   (116, 184),
#   (116, 185),
#   (116, 186),
#   (116, 187),
#   (116, 188),
#   (116, 189),
#   (117, 190),
#   (117, 191),
#   (117, 192),
#   (117, 193),
#   (117, 194),
#   (117, 195),
#   (118, 196),
#   (118, 197),
#   (118, 198),
#   (118, 199),
#   (118, 200),
#   (118, 201),
#   (118, 202),
#   (118, 203),
#   (118, 204),
#   (118, 205),
#   (119, 206),
#   (119, 207),
#   (119, 208),
#   (119, 209),
#   (119, 210),
#   (119, 211),
#   (119, 212),
#   (119, 213),
#   (119, 214),
#   (119, 215),
#   (119, 216),
#   (119, 217),
#   (119, 218),
#   (119, 219),
#   (119, 220),
#   (119, 221),
#   (119, 222),
#   (119, 223),
#   (119, 224),
#   (119, 225),
#   (119, 226),
#   (118, 227),
#   (118, 228),
#   (118, 229),
#   (118, 230),
#   (118, 231),
#   (118, 232),
#   (118, 233),
#   (118, 234),
#   (117, 235),
#   (117, 236),
#   (117, 237),
#   (117, 238),
#   (117, 239),
#   (116, 240),
#   (116, 241),
#   (116, 242),
#   (116, 243),
#   (115, 244),
#   (115, 245),
#   (115, 246),
#   (114, 247),
#   (114, 248),
#   (114, 249),
#   (114, 250),
#   (113, 251),
#   (113, 252),
#   (113, 253),
#   (112, 254),
#   (112, 255),
#   (112, 256),
#   (111, 257),
#   (111, 258),
#   (111, 259),
#   (110, 260),
#   (110, 261),
#   (110, 262),
#   (109, 263),
#   (109, 264),
#   (108, 265),
#   (108, 266),
#   (108, 267),
#   (107, 268),
#   (107, 269),
#   (106, 270),
#   (106, 271),
#   (106, 272),
#   (105, 273),
#   (105, 274),
#   (104, 275),
#   (104, 276),
#   (104, 277),
#   (103, 278),
#   (103, 279),
#   (102, 280),
#   (102, 281),
#   (102, 282),
#   (101, 283),
#   (101, 284),
#   (100, 285),
#   (100, 286),
#   (100, 287),
#   (99, 288),
#   (99, 289),
#   (99, 290),
#   (98, 291),
#   (98, 292),
#   (97, 293),
#   (97, 294),
#   (97, 295),
#   (96, 296),
#   (96, 297),
#   (95, 298),
#   (95, 299),
#   (95, 300),
#   (94, 301),
#   (94, 302),
#   (94, 303),
#   (93, 304),
#   (93, 305),
#   (93, 306),
#   (92, 307),
#   (92, 308),
#   (92, 309),
#   (91, 310),
#   (91, 311),
#   (91, 312),
#   (90, 313),
#   (90, 314),
#   (90, 315),
#   (89, 316),
#   (89, 317),
#   (89, 318),
#   (88, 319),
#   (88, 320),
#   (88, 321),
#   (88, 322),
#   (87, 323),
#   (87, 324),
#   (87, 325),
#   (87, 326),
#   (86, 327),
#   (86, 328),
#   (86, 329),
#   (86, 330),
#   (86, 331),
#   (85, 332),
#   (85, 333),
#   (85, 334),
#   (85, 335),
#   (85, 336),
#   (84, 337),
#   (84, 338),
#   (84, 339),
#   (84, 340),
#   (84, 341),
#   (84, 342),
#   (84, 343),
#   (83, 344),
#   (83, 345),
#   (83, 346),
#   (83, 347),
#   (83, 348),
#   (83, 349),
#   (83, 350),
#   (83, 351),
#   (83, 352),
#   (83, 353),
#   (82, 354),
#   (82, 355),
#   (82, 356),
#   (82, 357),
#   (82, 358),
#   (82, 359),
#   (82, 360),
#   (82, 361),
#   (82, 362),
#   (82, 363),
#   (82, 364),
#   (82, 365),
#   (82, 366),
#   (82, 367),
#   (82, 368),
#   (82, 369),
#   (82, 370),
#   (82, 371),
#   (82, 372),
#   (82, 373),
#   (82, 374),
#   (82, 375),
#   (82, 376),
#   (82, 377),
#   (83, 378),
#   (83, 379),
#   (83, 380),
#   (83, 381),
#   (83, 382),
#   (83, 383),
#   (83, 384),
#   (83, 385),
#   (83, 386),
#   (83, 387),
#   (84, 388),
#   (84, 389),
#   (84, 390),
#   (84, 391),
#   (84, 392),
#   (84, 393),
#   (84, 394),
#   (84, 395),
#   (85, 396),
#   (85, 397),
#   (85, 398),
#   (85, 399),
#   (85, 400),
#   (86, 401),
#   (86, 402),
#   (86, 403),
#   (86, 404),
#   (86, 405),
#   (86, 406),
#   (87, 407),
#   (87, 408),
#   (87, 409),
#   (87, 410),
#   (88, 411),
#   (88, 412),
#   (88, 413),
#   (88, 414),
#   (89, 415),
#   (89, 416),
#   (89, 417),
#   (89, 418),
#   (90, 419),
#   (90, 420),
#   (90, 421),
#   (90, 422),
#   (91, 423),
#   (91, 424),
#   (91, 425)]}

# %%
included_keys = ['UpperVertebra', 'LowerVertebra', 'EndVertebrae','COBBAngles']
d2={k:v for k,v in cad.cobbdata.items() if k in included_keys}
d2['EndVertebrae']=[v[0]+'-'+v[1] for v in d2['EndVertebrae']]

# %%
d2
# Out:
# {'UpperVertebra': 'T1',
#  'LowerVertebra': 'L5',
#  'EndVertebrae': ['T8-L1', 'L1-L4'],
#  'COBBAngles': [32, 27]}
